# %%
from vggFinetuneModel import FineTuneModel
from CIFAR_DataLoader import CifarDataManager
import numpy as np
import random

# %%
def one_hot(vec, vals=10):
    n = len(vec)
    out = np.zeros((n, vals))
    out[range(n), vec] = 1
    return out

def modify_label(labels, test_classes = [0]):
    test_classes.sort()
    tmp_labels = []
    for i in labels:
        if i in test_classes:
            tmp_labels.append(test_classes.index(i))
        else:
            tmp_labels.append(len(test_classes))
    return one_hot(tmp_labels, vals=len(test_classes)+1)

# %%
data_loader = CifarDataManager()

# %%
prune_ratio = 0.9
average = 0
for i in range(50):
    # test_classes = np.random.randint(100,size=5)
    # test_classes = test_classes.tolist()
    test_classes = random.sample(range(0,100),5);
    test_images, test_labels = data_loader.test.next_batch_without_onehot(200)
    test_labels = modify_label(test_labels, test_classes = test_classes)
    print("----------------------------------------------------------------------------------------------")
    model = FineTuneModel(target_class_id = test_classes, prune_ratio=prune_ratio)
    model.assign_weight()
    tmp = model.test_accuracy(test_images, test_labels)
    print("Class: ", test_classes)
    print("Before Fine-tune, Test Accuracy: " + str(tmp))
    for j in range(100):
        train_images, train_labels = data_loader.train.next_batch_without_onehot(500)
        train_labels = modify_label(train_labels, test_classes = test_classes)
        model.train_model(train_images, train_labels)
        accuracy = model.test_accuracy(test_images, test_labels)
        if (j == 99):
            print("After One Hundred Iterations, Test Accuracy:" + str(accuracy))
            average += accuracy
    print("----------------------------------------------------------------------------------------------")
print("AVERAGE ACCURACY: ",str(average*1.0/50))
# Out:
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.9
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [2, 12, 33, 85, 99]
# Before Fine-tune, Test Accuracy: 0.005
# After One Hundred Iterations, Test Accuracy:0.96
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.9
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [0, 18, 25, 42, 98]
# Before Fine-tune, Test Accuracy: 0.005
# After One Hundred Iterations, Test Accuracy:0.935
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.9
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [59, 73, 76, 92, 97]
# Before Fine-tune, Test Accuracy: 0.975
# After One Hundred Iterations, Test Accuracy:0.975
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.9
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [9, 18, 34, 67, 86]
# Before Fine-tune, Test Accuracy: 0.005
# After One Hundred Iterations, Test Accuracy:0.97
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.9
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [0, 10, 27, 39, 40]
# Before Fine-tune, Test Accuracy: 0.0
# After One Hundred Iterations, Test Accuracy:0.96
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.9
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [0, 24, 51, 89, 95]
# Before Fine-tune, Test Accuracy: 0.015
# After One Hundred Iterations, Test Accuracy:0.94
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.9
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [7, 23, 29, 52, 74]
# Before Fine-tune, Test Accuracy: 0.01
# After One Hundred Iterations, Test Accuracy:0.965
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.9
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [9, 21, 68, 70, 82]
# Before Fine-tune, Test Accuracy: 0.955
# After One Hundred Iterations, Test Accuracy:0.955
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.9
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [3, 7, 44, 69, 96]
# Before Fine-tune, Test Accuracy: 0.015
# After One Hundred Iterations, Test Accuracy:0.925
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.9
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [18, 31, 36, 44, 95]
# Before Fine-tune, Test Accuracy: 0.03
# After One Hundred Iterations, Test Accuracy:0.905
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.9
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [0, 4, 58, 67, 86]
# Before Fine-tune, Test Accuracy: 0.015
# After One Hundred Iterations, Test Accuracy:0.95
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.9
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [23, 35, 62, 76, 99]
# Before Fine-tune, Test Accuracy: 0.01
# After One Hundred Iterations, Test Accuracy:0.94
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.9
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [28, 62, 74, 77, 97]
# Before Fine-tune, Test Accuracy: 0.005
# After One Hundred Iterations, Test Accuracy:0.975
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.9
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [33, 38, 49, 72, 76]
# Before Fine-tune, Test Accuracy: 0.015
# After One Hundred Iterations, Test Accuracy:0.945
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.9
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [0, 6, 35, 67, 97]
# Before Fine-tune, Test Accuracy: 0.015
# After One Hundred Iterations, Test Accuracy:0.925
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.9
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [23, 66, 79, 86, 99]
# Before Fine-tune, Test Accuracy: 0.02
# After One Hundred Iterations, Test Accuracy:0.95
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.9
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [11, 47, 70, 71, 72]
# Before Fine-tune, Test Accuracy: 0.015
# After One Hundred Iterations, Test Accuracy:0.96
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.9
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [20, 44, 53, 55, 90]
# Before Fine-tune, Test Accuracy: 0.005
# After One Hundred Iterations, Test Accuracy:0.955
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.9
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [20, 49, 80, 91, 97]
# Before Fine-tune, Test Accuracy: 0.005
# After One Hundred Iterations, Test Accuracy:0.94
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.9
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [4, 15, 18, 60, 82]
# Before Fine-tune, Test Accuracy: 0.02
# After One Hundred Iterations, Test Accuracy:0.935
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.9
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [10, 11, 72, 91, 95]
# Before Fine-tune, Test Accuracy: 0.03
# After One Hundred Iterations, Test Accuracy:0.93
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.9
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [22, 60, 69, 71, 89]
# Before Fine-tune, Test Accuracy: 0.015
# After One Hundred Iterations, Test Accuracy:0.97
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.9
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [4, 24, 26, 54, 79]
# Before Fine-tune, Test Accuracy: 0.025
# After One Hundred Iterations, Test Accuracy:0.94
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.9
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [47, 48, 53, 67, 85]
# Before Fine-tune, Test Accuracy: 0.975
# After One Hundred Iterations, Test Accuracy:0.975
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.9
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [12, 31, 55, 58, 64]
# Before Fine-tune, Test Accuracy: 0.01
# After One Hundred Iterations, Test Accuracy:0.935
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.9
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [5, 6, 29, 81, 83]
# Before Fine-tune, Test Accuracy: 0.01
# After One Hundred Iterations, Test Accuracy:0.945
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.9
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [19, 55, 63, 82, 98]
# Before Fine-tune, Test Accuracy: 0.015
# After One Hundred Iterations, Test Accuracy:0.96
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.9
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [0, 23, 26, 61, 95]
# Before Fine-tune, Test Accuracy: 0.0
# After One Hundred Iterations, Test Accuracy:0.965
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.9
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [16, 18, 63, 69, 71]
# Before Fine-tune, Test Accuracy: 0.005
# After One Hundred Iterations, Test Accuracy:0.95
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.9
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [23, 57, 66, 78, 94]
# Before Fine-tune, Test Accuracy: 0.01
# After One Hundred Iterations, Test Accuracy:0.95
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.9
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [16, 23, 41, 65, 85]
# Before Fine-tune, Test Accuracy: 0.0
# After One Hundred Iterations, Test Accuracy:0.95
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.9
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [6, 8, 17, 18, 71]
# Before Fine-tune, Test Accuracy: 0.005
# After One Hundred Iterations, Test Accuracy:0.955
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.9
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [16, 27, 53, 76, 91]
# Before Fine-tune, Test Accuracy: 0.005
# After One Hundred Iterations, Test Accuracy:0.95
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.9
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [6, 24, 51, 70, 86]
# Before Fine-tune, Test Accuracy: 0.015
# After One Hundred Iterations, Test Accuracy:0.95
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.9
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [5, 9, 26, 53, 95]
# Before Fine-tune, Test Accuracy: 0.005
# After One Hundred Iterations, Test Accuracy:0.96
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.9
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [22, 27, 79, 86, 92]
# Before Fine-tune, Test Accuracy: 0.015
# After One Hundred Iterations, Test Accuracy:0.975
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.9
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [19, 20, 35, 41, 75]
# Before Fine-tune, Test Accuracy: 0.02
# After One Hundred Iterations, Test Accuracy:0.91
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.9
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [18, 36, 42, 67, 88]
# Before Fine-tune, Test Accuracy: 0.005
# After One Hundred Iterations, Test Accuracy:0.95
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.9
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [1, 27, 44, 61, 72]
# Before Fine-tune, Test Accuracy: 0.015
# After One Hundred Iterations, Test Accuracy:0.95
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.9
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [17, 35, 42, 44, 66]
# Before Fine-tune, Test Accuracy: 0.01
# After One Hundred Iterations, Test Accuracy:0.94
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.9
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [10, 25, 42, 87, 97]
# Before Fine-tune, Test Accuracy: 0.005
# After One Hundred Iterations, Test Accuracy:0.975
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.9
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [1, 32, 37, 73, 89]
# Before Fine-tune, Test Accuracy: 0.015
# After One Hundred Iterations, Test Accuracy:0.945
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.9
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [18, 22, 47, 51, 66]
# Before Fine-tune, Test Accuracy: 0.005
# After One Hundred Iterations, Test Accuracy:0.955
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.9
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [51, 62, 68, 86, 90]
# Before Fine-tune, Test Accuracy: 0.95
# After One Hundred Iterations, Test Accuracy:0.95
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.9
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [35, 48, 49, 82, 83]
# Before Fine-tune, Test Accuracy: 0.005
# After One Hundred Iterations, Test Accuracy:0.945
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.9
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [9, 20, 30, 63, 86]
# Before Fine-tune, Test Accuracy: 0.02
# After One Hundred Iterations, Test Accuracy:0.945
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.9
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [5, 16, 23, 27, 93]
# Before Fine-tune, Test Accuracy: 0.005
# After One Hundred Iterations, Test Accuracy:0.975
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.9
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [11, 71, 75, 94, 96]
# Before Fine-tune, Test Accuracy: 0.0
# After One Hundred Iterations, Test Accuracy:0.97
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.9
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [4, 9, 15, 41, 46]
# Before Fine-tune, Test Accuracy: 0.015
# After One Hundred Iterations, Test Accuracy:0.93
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.9
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [4, 9, 55, 75, 85]
# Before Fine-tune, Test Accuracy: 0.01
# After One Hundred Iterations, Test Accuracy:0.935
# ----------------------------------------------------------------------------------------------
# AVERAGE ACCURACY:  0.9499999976158142

# %%
prune_ratio = 0.95
average = 0
for i in range(50):
    # test_classes = np.random.randint(100,size=5)
    # test_classes = test_classes.tolist()
    test_classes = random.sample(range(0,100),5);
    test_images, test_labels = data_loader.test.next_batch_without_onehot(200)
    test_labels = modify_label(test_labels, test_classes = test_classes)
    print("----------------------------------------------------------------------------------------------")
    model = FineTuneModel(target_class_id = test_classes, prune_ratio=prune_ratio)
    model.assign_weight()
    tmp = model.test_accuracy(test_images, test_labels)
    print("Class: ", test_classes)
    print("Before Fine-tune, Test Accuracy: " + str(tmp))
    for j in range(100):
        train_images, train_labels = data_loader.train.next_batch_without_onehot(500)
        train_labels = modify_label(train_labels, test_classes = test_classes)
        model.train_model(train_images, train_labels)
        accuracy = model.test_accuracy(test_images, test_labels)
        if (j == 99):
            print("After One Hundred Iterations, Test Accuracy:" + str(accuracy))
            average += accuracy
    print("----------------------------------------------------------------------------------------------")
print("AVERAGE ACCURACY: ",str(average*1.0/50))
# Out:
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.95
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [0, 47, 60, 79, 84]
# Before Fine-tune, Test Accuracy: 0.975
# After One Hundred Iterations, Test Accuracy:0.975
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.95
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [24, 72, 74, 81, 98]
# Before Fine-tune, Test Accuracy: 0.005
# After One Hundred Iterations, Test Accuracy:0.97
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.95
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [21, 31, 34, 49, 93]
# Before Fine-tune, Test Accuracy: 0.015
# After One Hundred Iterations, Test Accuracy:0.965
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.95
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [0, 6, 48, 73, 99]
# Before Fine-tune, Test Accuracy: 0.01
# After One Hundred Iterations, Test Accuracy:0.935
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.95
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [17, 25, 57, 66, 88]
# Before Fine-tune, Test Accuracy: 0.0
# After One Hundred Iterations, Test Accuracy:0.965
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.95
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [10, 49, 58, 78, 93]
# Before Fine-tune, Test Accuracy: 0.03
# After One Hundred Iterations, Test Accuracy:0.925
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.95
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [42, 59, 82, 91, 94]
# Before Fine-tune, Test Accuracy: 0.95
# After One Hundred Iterations, Test Accuracy:0.95
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.95
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [9, 10, 16, 33, 72]
# Before Fine-tune, Test Accuracy: 0.02
# After One Hundred Iterations, Test Accuracy:0.935
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.95
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [8, 28, 35, 44, 60]
# Before Fine-tune, Test Accuracy: 0.01
# After One Hundred Iterations, Test Accuracy:0.96
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.95
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [14, 47, 58, 66, 88]
# Before Fine-tune, Test Accuracy: 0.01
# After One Hundred Iterations, Test Accuracy:0.955
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.95
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [7, 10, 70, 85, 96]
# Before Fine-tune, Test Accuracy: 0.005
# After One Hundred Iterations, Test Accuracy:0.97
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.95
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [3, 10, 12, 29, 59]
# Before Fine-tune, Test Accuracy: 0.02
# After One Hundred Iterations, Test Accuracy:0.935
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.95
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [0, 26, 29, 33, 60]
# Before Fine-tune, Test Accuracy: 0.025
# After One Hundred Iterations, Test Accuracy:0.91
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.95
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [10, 23, 43, 71, 89]
# Before Fine-tune, Test Accuracy: 0.01
# After One Hundred Iterations, Test Accuracy:0.945
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.95
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [29, 33, 53, 55, 62]
# Before Fine-tune, Test Accuracy: 0.0
# After One Hundred Iterations, Test Accuracy:0.97
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.95
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [33, 46, 49, 79, 85]
# Before Fine-tune, Test Accuracy: 0.015
# After One Hundred Iterations, Test Accuracy:0.95
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.95
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [8, 15, 31, 83, 98]
# Before Fine-tune, Test Accuracy: 0.01
# After One Hundred Iterations, Test Accuracy:0.97
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.95
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [52, 54, 56, 76, 93]
# Before Fine-tune, Test Accuracy: 0.935
# After One Hundred Iterations, Test Accuracy:0.935
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.95
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [0, 47, 61, 82, 96]
# Before Fine-tune, Test Accuracy: 0.94
# After One Hundred Iterations, Test Accuracy:0.94
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.95
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [19, 29, 47, 73, 94]
# Before Fine-tune, Test Accuracy: 0.005
# After One Hundred Iterations, Test Accuracy:0.95
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.95
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [39, 56, 70, 73, 90]
# Before Fine-tune, Test Accuracy: 0.005
# After One Hundred Iterations, Test Accuracy:0.975
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.95
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [18, 33, 37, 94, 96]
# Before Fine-tune, Test Accuracy: 0.01
# After One Hundred Iterations, Test Accuracy:0.95
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.95
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [7, 20, 65, 66, 97]
# Before Fine-tune, Test Accuracy: 0.01
# After One Hundred Iterations, Test Accuracy:0.93
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.95
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [58, 90, 94, 95, 98]
# Before Fine-tune, Test Accuracy: 0.955
# After One Hundred Iterations, Test Accuracy:0.955
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.95
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [1, 2, 5, 52, 87]
# Before Fine-tune, Test Accuracy: 0.005
# After One Hundred Iterations, Test Accuracy:0.96
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.95
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [12, 33, 49, 86, 95]
# Before Fine-tune, Test Accuracy: 0.01
# After One Hundred Iterations, Test Accuracy:0.94
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.95
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [11, 23, 59, 79, 94]
# Before Fine-tune, Test Accuracy: 0.005
# After One Hundred Iterations, Test Accuracy:0.965
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.95
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [0, 2, 68, 76, 98]
# Before Fine-tune, Test Accuracy: 0.955
# After One Hundred Iterations, Test Accuracy:0.955
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.95
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [15, 24, 30, 56, 73]
# Before Fine-tune, Test Accuracy: 0.02
# After One Hundred Iterations, Test Accuracy:0.925
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.95
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [5, 7, 31, 74, 86]
# Before Fine-tune, Test Accuracy: 0.015
# After One Hundred Iterations, Test Accuracy:0.935
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.95
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [0, 7, 15, 18, 75]
# Before Fine-tune, Test Accuracy: 0.97
# After One Hundred Iterations, Test Accuracy:0.97
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.95
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [7, 66, 72, 95, 98]
# Before Fine-tune, Test Accuracy: 0.01
# After One Hundred Iterations, Test Accuracy:0.935
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.95
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [2, 34, 41, 68, 87]
# Before Fine-tune, Test Accuracy: 0.015
# After One Hundred Iterations, Test Accuracy:0.96
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.95
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [18, 33, 77, 82, 83]
# Before Fine-tune, Test Accuracy: 0.015
# After One Hundred Iterations, Test Accuracy:0.955
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.95
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [3, 34, 42, 50, 85]
# Before Fine-tune, Test Accuracy: 0.96
# After One Hundred Iterations, Test Accuracy:0.96
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.95
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [2, 3, 15, 58, 91]
# Before Fine-tune, Test Accuracy: 0.01
# After One Hundred Iterations, Test Accuracy:0.955
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.95
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [35, 79, 82, 92, 93]
# Before Fine-tune, Test Accuracy: 0.02
# After One Hundred Iterations, Test Accuracy:0.925
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.95
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [7, 60, 91, 94, 96]
# Before Fine-tune, Test Accuracy: 0.01
# After One Hundred Iterations, Test Accuracy:0.945
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.95
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [8, 60, 72, 80, 94]
# Before Fine-tune, Test Accuracy: 0.015
# After One Hundred Iterations, Test Accuracy:0.94
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.95
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [17, 43, 58, 73, 91]
# Before Fine-tune, Test Accuracy: 0.915
# After One Hundred Iterations, Test Accuracy:0.915
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.95
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [11, 49, 64, 80, 93]
# Before Fine-tune, Test Accuracy: 0.005
# After One Hundred Iterations, Test Accuracy:0.965
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.95
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [6, 9, 29, 45, 68]
# Before Fine-tune, Test Accuracy: 0.01
# After One Hundred Iterations, Test Accuracy:0.955
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.95
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [3, 13, 40, 47, 49]
# Before Fine-tune, Test Accuracy: 0.01
# After One Hundred Iterations, Test Accuracy:0.95
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.95
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [46, 64, 84, 94, 98]
# Before Fine-tune, Test Accuracy: 0.005
# After One Hundred Iterations, Test Accuracy:0.94
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.95
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [36, 48, 58, 59, 74]
# Before Fine-tune, Test Accuracy: 0.01
# After One Hundred Iterations, Test Accuracy:0.945
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.95
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [8, 22, 23, 35, 63]
# Before Fine-tune, Test Accuracy: 0.015
# After One Hundred Iterations, Test Accuracy:0.95
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.95
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [55, 57, 58, 86, 95]
# Before Fine-tune, Test Accuracy: 0.01
# After One Hundred Iterations, Test Accuracy:0.94
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.95
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [9, 16, 28, 42, 47]
# Before Fine-tune, Test Accuracy: 0.955
# After One Hundred Iterations, Test Accuracy:0.955
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.95
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [1, 29, 31, 76, 91]
# Before Fine-tune, Test Accuracy: 0.01
# After One Hundred Iterations, Test Accuracy:0.935
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.95
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [32, 35, 67, 74, 94]
# Before Fine-tune, Test Accuracy: 0.965
# After One Hundred Iterations, Test Accuracy:0.965
# ----------------------------------------------------------------------------------------------
# AVERAGE ACCURACY:  0.9491999971866608

# %%
prune_ratio = 0.99
average = 0
for i in range(50):
    # test_classes = np.random.randint(100,size=5)
    # test_classes = test_classes.tolist()
    test_classes = random.sample(range(0,100),5);
    test_images, test_labels = data_loader.test.next_batch_without_onehot(200)
    test_labels = modify_label(test_labels, test_classes = test_classes)
    print("----------------------------------------------------------------------------------------------")
    model = FineTuneModel(target_class_id = test_classes, prune_ratio=prune_ratio)
    model.assign_weight()
    tmp = model.test_accuracy(test_images, test_labels)
    print("Class: ", test_classes)
    print("Before Fine-tune, Test Accuracy: " + str(tmp))
    for j in range(100):
        train_images, train_labels = data_loader.train.next_batch_without_onehot(500)
        train_labels = modify_label(train_labels, test_classes = test_classes)
        model.train_model(train_images, train_labels)
        accuracy = model.test_accuracy(test_images, test_labels)
        if (j == 99):
            print("After One Hundred Iterations, Test Accuracy:" + str(accuracy))
            average += accuracy
    print("----------------------------------------------------------------------------------------------")
print("AVERAGE ACCURACY: ",str(average*1.0/50))
# Out:
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.99
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [25, 26, 49, 78, 90]
# Before Fine-tune, Test Accuracy: 0.015
# After One Hundred Iterations, Test Accuracy:0.95
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.99
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [7, 14, 35, 42, 90]
# Before Fine-tune, Test Accuracy: 0.94
# After One Hundred Iterations, Test Accuracy:0.94
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.99
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [22, 51, 78, 86, 99]
# Before Fine-tune, Test Accuracy: 0.005
# After One Hundred Iterations, Test Accuracy:0.955
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.99
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [2, 15, 18, 59, 64]
# Before Fine-tune, Test Accuracy: 0.0
# After One Hundred Iterations, Test Accuracy:0.955
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.99
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [15, 34, 50, 83, 95]
# Before Fine-tune, Test Accuracy: 0.0
# After One Hundred Iterations, Test Accuracy:0.965
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.99
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [28, 29, 34, 66, 98]
# Before Fine-tune, Test Accuracy: 0.005
# After One Hundred Iterations, Test Accuracy:0.945
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.99
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [31, 48, 61, 67, 88]
# Before Fine-tune, Test Accuracy: 0.005
# After One Hundred Iterations, Test Accuracy:0.945
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.99
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [27, 33, 37, 91, 95]
# Before Fine-tune, Test Accuracy: 0.005
# After One Hundred Iterations, Test Accuracy:0.96
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.99
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [27, 77, 84, 87, 97]
# Before Fine-tune, Test Accuracy: 0.025
# After One Hundred Iterations, Test Accuracy:0.96
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.99
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [2, 22, 32, 86, 95]
# Before Fine-tune, Test Accuracy: 0.92
# After One Hundred Iterations, Test Accuracy:0.92
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.99
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [8, 51, 64, 78, 81]
# Before Fine-tune, Test Accuracy: 0.015
# After One Hundred Iterations, Test Accuracy:0.955
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.99
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [9, 11, 14, 25, 89]
# Before Fine-tune, Test Accuracy: 0.955
# After One Hundred Iterations, Test Accuracy:0.955
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.99
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [8, 50, 56, 72, 82]
# Before Fine-tune, Test Accuracy: 0.015
# After One Hundred Iterations, Test Accuracy:0.945
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.99
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [14, 33, 43, 59, 98]
# Before Fine-tune, Test Accuracy: 0.0
# After One Hundred Iterations, Test Accuracy:0.975
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.99
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [17, 41, 53, 93, 98]
# Before Fine-tune, Test Accuracy: 0.02
# After One Hundred Iterations, Test Accuracy:0.94
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.99
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [7, 24, 52, 88, 93]
# Before Fine-tune, Test Accuracy: 0.94
# After One Hundred Iterations, Test Accuracy:0.94
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.99
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [20, 46, 62, 74, 99]
# Before Fine-tune, Test Accuracy: 0.035
# After One Hundred Iterations, Test Accuracy:0.905
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.99
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [19, 32, 37, 56, 78]
# Before Fine-tune, Test Accuracy: 0.015
# After One Hundred Iterations, Test Accuracy:0.93
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.99
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [10, 58, 82, 86, 89]
# Before Fine-tune, Test Accuracy: 0.005
# After One Hundred Iterations, Test Accuracy:0.945
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.99
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [16, 34, 43, 75, 85]
# Before Fine-tune, Test Accuracy: 0.015
# After One Hundred Iterations, Test Accuracy:0.955
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.99
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [1, 9, 45, 51, 57]
# Before Fine-tune, Test Accuracy: 0.955
# After One Hundred Iterations, Test Accuracy:0.955
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.99
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [38, 42, 64, 92, 93]
# Before Fine-tune, Test Accuracy: 0.945
# After One Hundred Iterations, Test Accuracy:0.945
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.99
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [27, 28, 39, 52, 74]
# Before Fine-tune, Test Accuracy: 0.93
# After One Hundred Iterations, Test Accuracy:0.93
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.99
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [47, 65, 67, 71, 72]
# Before Fine-tune, Test Accuracy: 0.01
# After One Hundred Iterations, Test Accuracy:0.955
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.99
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [22, 40, 53, 58, 84]
# Before Fine-tune, Test Accuracy: 0.005
# After One Hundred Iterations, Test Accuracy:0.95
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.99
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [47, 64, 81, 94, 95]
# Before Fine-tune, Test Accuracy: 0.955
# After One Hundred Iterations, Test Accuracy:0.955
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.99
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [27, 29, 39, 87, 88]
# Before Fine-tune, Test Accuracy: 0.015
# After One Hundred Iterations, Test Accuracy:0.94
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.99
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [5, 7, 16, 30, 70]
# Before Fine-tune, Test Accuracy: 0.02
# After One Hundred Iterations, Test Accuracy:0.905
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.99
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [11, 36, 38, 73, 84]
# Before Fine-tune, Test Accuracy: 0.95
# After One Hundred Iterations, Test Accuracy:0.95
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.99
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [5, 12, 23, 37, 49]
# Before Fine-tune, Test Accuracy: 0.01
# After One Hundred Iterations, Test Accuracy:0.96
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.99
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [7, 12, 13, 35, 46]
# Before Fine-tune, Test Accuracy: 0.005
# After One Hundred Iterations, Test Accuracy:0.96
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.99
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [2, 6, 53, 62, 98]
# Before Fine-tune, Test Accuracy: 0.035
# After One Hundred Iterations, Test Accuracy:0.95
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.99
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [34, 65, 71, 82, 99]
# Before Fine-tune, Test Accuracy: 0.94
# After One Hundred Iterations, Test Accuracy:0.94
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.99
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [5, 16, 38, 52, 56]
# Before Fine-tune, Test Accuracy: 0.005
# After One Hundred Iterations, Test Accuracy:0.97
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.99
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [4, 19, 20, 27, 76]
# Before Fine-tune, Test Accuracy: 0.935
# After One Hundred Iterations, Test Accuracy:0.935
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.99
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [3, 27, 55, 74, 84]
# Before Fine-tune, Test Accuracy: 0.005
# After One Hundred Iterations, Test Accuracy:0.96
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.99
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [7, 35, 64, 94, 96]
# Before Fine-tune, Test Accuracy: 0.015
# After One Hundred Iterations, Test Accuracy:0.95
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.99
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [10, 22, 53, 58, 61]
# Before Fine-tune, Test Accuracy: 0.01
# After One Hundred Iterations, Test Accuracy:0.95
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.99
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [5, 40, 51, 55, 58]
# Before Fine-tune, Test Accuracy: 0.93
# After One Hundred Iterations, Test Accuracy:0.93
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.99
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [14, 20, 25, 41, 71]
# Before Fine-tune, Test Accuracy: 0.965
# After One Hundred Iterations, Test Accuracy:0.965
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.99
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [24, 30, 63, 80, 88]
# Before Fine-tune, Test Accuracy: 0.0
# After One Hundred Iterations, Test Accuracy:0.97
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.99
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [18, 47, 49, 76, 94]
# Before Fine-tune, Test Accuracy: 0.01
# After One Hundred Iterations, Test Accuracy:0.935
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.99
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [5, 12, 51, 69, 84]
# Before Fine-tune, Test Accuracy: 0.005
# After One Hundred Iterations, Test Accuracy:0.96
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.99
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [33, 43, 53, 72, 80]
# Before Fine-tune, Test Accuracy: 0.02
# After One Hundred Iterations, Test Accuracy:0.945
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.99
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [6, 24, 28, 55, 99]
# Before Fine-tune, Test Accuracy: 0.01
# After One Hundred Iterations, Test Accuracy:0.955
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.99
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [5, 11, 36, 67, 79]
# Before Fine-tune, Test Accuracy: 0.01
# After One Hundred Iterations, Test Accuracy:0.965
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.99
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [25, 42, 66, 86, 99]
# Before Fine-tune, Test Accuracy: 0.005
# After One Hundred Iterations, Test Accuracy:0.955
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.99
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [11, 62, 65, 67, 83]
# Before Fine-tune, Test Accuracy: 0.01
# After One Hundred Iterations, Test Accuracy:0.96
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.99
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [27, 83, 84, 92, 94]
# Before Fine-tune, Test Accuracy: 0.01
# After One Hundred Iterations, Test Accuracy:0.96
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.99
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [3, 14, 31, 41, 99]
# Before Fine-tune, Test Accuracy: 0.02
# After One Hundred Iterations, Test Accuracy:0.925
# ----------------------------------------------------------------------------------------------
# AVERAGE ACCURACY:  0.9484999907016755
