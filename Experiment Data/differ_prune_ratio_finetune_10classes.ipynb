# %%
from vggFinetuneModel import FineTuneModel
from CIFAR_DataLoader import CifarDataManager
import numpy as np
import random
# Out:
# Using TensorFlow backend.

# %%
def one_hot(vec, vals=10):
    n = len(vec)
    out = np.zeros((n, vals))
    out[range(n), vec] = 1
    return out

def modify_label(labels, test_classes = [0]):
    test_classes.sort()
    tmp_labels = []
    for i in labels:
        if i in test_classes:
            tmp_labels.append(test_classes.index(i))
        else:
            tmp_labels.append(len(test_classes))
    return one_hot(tmp_labels, vals=len(test_classes)+1)

# %%
data_loader = CifarDataManager()

# %%
prune_ratio = 0.9
average = 0
for i in range(50):
    # test_classes = np.random.randint(100,size=10)
    # test_classes = test_classes.tolist()
    test_classes = random.sample(range(0,100),10);
    test_images, test_labels = data_loader.test.next_batch_without_onehot(200)
    test_labels = modify_label(test_labels, test_classes = test_classes)
    print("----------------------------------------------------------------------------------------------")
    model = FineTuneModel(target_class_id = test_classes, prune_ratio=prune_ratio)
    model.assign_weight()
    tmp = model.test_accuracy(test_images, test_labels)
    print("Class: ", test_classes)
    print("Before Fine-tune, Test Accuracy: " + str(tmp))
    for j in range(100):
        train_images, train_labels = data_loader.train.next_batch_without_onehot(500)
        train_labels = modify_label(train_labels, test_classes = test_classes)
        model.train_model(train_images, train_labels)
        accuracy = model.test_accuracy(test_images, test_labels)
        if (j == 99):
            print("After One Hundred Iterations, Test Accuracy:" + str(accuracy))
            average += accuracy
    print("----------------------------------------------------------------------------------------------")
print("AVERAGE ACCURACY: ",str(average*1.0/50))
# Out:
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.9
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [8, 14, 45, 58, 60, 61, 63, 74, 78, 85]
# Before Fine-tune, Test Accuracy: 0.005
# After One Hundred Iterations, Test Accuracy:0.89
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.9
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [6, 11, 18, 23, 41, 62, 67, 76, 83, 94]
# Before Fine-tune, Test Accuracy: 0.82
# After One Hundred Iterations, Test Accuracy:0.82
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.9
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [8, 10, 18, 37, 49, 55, 69, 75, 79, 85]
# Before Fine-tune, Test Accuracy: 0.01
# After One Hundred Iterations, Test Accuracy:0.87
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.9
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [2, 3, 13, 30, 36, 46, 54, 56, 70, 83]
# Before Fine-tune, Test Accuracy: 0.005
# After One Hundred Iterations, Test Accuracy:0.91
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.9
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [1, 5, 18, 20, 30, 33, 54, 60, 61, 91]
# Before Fine-tune, Test Accuracy: 0.0
# After One Hundred Iterations, Test Accuracy:0.93
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.9
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [10, 19, 23, 25, 42, 46, 49, 65, 73, 90]
# Before Fine-tune, Test Accuracy: 0.87
# After One Hundred Iterations, Test Accuracy:0.87
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.9
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [3, 25, 27, 35, 36, 54, 66, 72, 76, 83]
# Before Fine-tune, Test Accuracy: 0.01
# After One Hundred Iterations, Test Accuracy:0.91
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.9
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [22, 29, 32, 33, 37, 39, 71, 79, 82, 92]
# Before Fine-tune, Test Accuracy: 0.005
# After One Hundred Iterations, Test Accuracy:0.89
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.9
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [0, 11, 22, 39, 40, 52, 54, 72, 77, 79]
# Before Fine-tune, Test Accuracy: 0.0
# After One Hundred Iterations, Test Accuracy:0.92
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.9
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [5, 7, 26, 31, 39, 68, 89, 91, 93, 97]
# Before Fine-tune, Test Accuracy: 0.005
# After One Hundred Iterations, Test Accuracy:0.91
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.9
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [11, 14, 16, 22, 29, 33, 41, 49, 66, 87]
# Before Fine-tune, Test Accuracy: 0.015
# After One Hundred Iterations, Test Accuracy:0.85
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.9
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [6, 16, 28, 31, 32, 33, 52, 77, 91, 92]
# Before Fine-tune, Test Accuracy: 0.01
# After One Hundred Iterations, Test Accuracy:0.91
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.9
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [1, 15, 32, 47, 53, 56, 60, 68, 84, 97]
# Before Fine-tune, Test Accuracy: 0.0
# After One Hundred Iterations, Test Accuracy:0.925
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.9
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [0, 1, 7, 28, 29, 54, 62, 68, 74, 81]
# Before Fine-tune, Test Accuracy: 0.925
# After One Hundred Iterations, Test Accuracy:0.925
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.9
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [12, 14, 22, 30, 36, 37, 38, 70, 84, 85]
# Before Fine-tune, Test Accuracy: 0.02
# After One Hundred Iterations, Test Accuracy:0.89
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.9
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [0, 3, 17, 30, 31, 33, 54, 57, 59, 78]
# Before Fine-tune, Test Accuracy: 0.025
# After One Hundred Iterations, Test Accuracy:0.86
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.9
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [6, 16, 19, 42, 43, 57, 68, 69, 79, 99]
# Before Fine-tune, Test Accuracy: 0.025
# After One Hundred Iterations, Test Accuracy:0.835
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.9
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [2, 36, 42, 49, 55, 63, 66, 67, 71, 88]
# Before Fine-tune, Test Accuracy: 0.02
# After One Hundred Iterations, Test Accuracy:0.92
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.9
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [12, 15, 29, 43, 70, 73, 80, 82, 88, 94]
# Before Fine-tune, Test Accuracy: 0.0
# After One Hundred Iterations, Test Accuracy:0.9
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.9
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [13, 16, 22, 47, 51, 54, 67, 76, 85, 91]
# Before Fine-tune, Test Accuracy: 0.015
# After One Hundred Iterations, Test Accuracy:0.885
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.9
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [0, 9, 16, 23, 52, 68, 70, 73, 77, 96]
# Before Fine-tune, Test Accuracy: 0.915
# After One Hundred Iterations, Test Accuracy:0.915
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.9
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [7, 12, 13, 25, 38, 39, 43, 47, 81, 99]
# Before Fine-tune, Test Accuracy: 0.91
# After One Hundred Iterations, Test Accuracy:0.91
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.9
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [29, 38, 39, 41, 45, 48, 58, 68, 73, 99]
# Before Fine-tune, Test Accuracy: 0.0
# After One Hundred Iterations, Test Accuracy:0.91
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.9
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [10, 11, 20, 36, 43, 50, 54, 72, 76, 77]
# Before Fine-tune, Test Accuracy: 0.0
# After One Hundred Iterations, Test Accuracy:0.92
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.9
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [8, 22, 43, 46, 57, 68, 73, 75, 89, 92]
# Before Fine-tune, Test Accuracy: 0.0
# After One Hundred Iterations, Test Accuracy:0.92
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.9
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [4, 12, 25, 41, 49, 57, 66, 71, 82, 91]
# Before Fine-tune, Test Accuracy: 0.01
# After One Hundred Iterations, Test Accuracy:0.855
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.9
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [15, 29, 33, 37, 40, 53, 56, 61, 73, 74]
# Before Fine-tune, Test Accuracy: 0.005
# After One Hundred Iterations, Test Accuracy:0.885
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.9
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [34, 40, 41, 47, 50, 54, 76, 82, 86, 97]
# Before Fine-tune, Test Accuracy: 0.01
# After One Hundred Iterations, Test Accuracy:0.93
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.9
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [2, 9, 31, 58, 69, 77, 81, 85, 86, 88]
# Before Fine-tune, Test Accuracy: 0.02
# After One Hundred Iterations, Test Accuracy:0.875
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.9
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [10, 33, 47, 52, 59, 70, 73, 75, 86, 91]
# Before Fine-tune, Test Accuracy: 0.015
# After One Hundred Iterations, Test Accuracy:0.91
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.9
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [8, 14, 19, 32, 35, 38, 40, 52, 60, 89]
# Before Fine-tune, Test Accuracy: 0.01
# After One Hundred Iterations, Test Accuracy:0.92
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.9
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [22, 33, 43, 48, 56, 63, 64, 67, 80, 87]
# Before Fine-tune, Test Accuracy: 0.01
# After One Hundred Iterations, Test Accuracy:0.89
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.9
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [7, 15, 16, 30, 36, 41, 47, 51, 68, 78]
# Before Fine-tune, Test Accuracy: 0.01
# After One Hundred Iterations, Test Accuracy:0.885
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.9
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [1, 40, 46, 48, 62, 63, 67, 74, 86, 98]
# Before Fine-tune, Test Accuracy: 0.015
# After One Hundred Iterations, Test Accuracy:0.91
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.9
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [18, 22, 29, 48, 49, 51, 57, 73, 85, 98]
# Before Fine-tune, Test Accuracy: 0.015
# After One Hundred Iterations, Test Accuracy:0.905
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.9
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [2, 5, 9, 17, 22, 25, 32, 42, 71, 79]
# Before Fine-tune, Test Accuracy: 0.9
# After One Hundred Iterations, Test Accuracy:0.9
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.9
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [1, 14, 27, 30, 34, 35, 78, 87, 90, 99]
# Before Fine-tune, Test Accuracy: 0.01
# After One Hundred Iterations, Test Accuracy:0.87
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.9
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [6, 15, 17, 19, 29, 41, 54, 70, 74, 99]
# Before Fine-tune, Test Accuracy: 0.005
# After One Hundred Iterations, Test Accuracy:0.905
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.9
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [11, 14, 17, 23, 29, 34, 38, 62, 69, 95]
# Before Fine-tune, Test Accuracy: 0.01
# After One Hundred Iterations, Test Accuracy:0.925
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.9
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [16, 17, 39, 40, 58, 62, 63, 68, 74, 76]
# Before Fine-tune, Test Accuracy: 0.005
# After One Hundred Iterations, Test Accuracy:0.885
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.9
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [0, 4, 32, 49, 53, 58, 67, 70, 90, 95]
# Before Fine-tune, Test Accuracy: 0.01
# After One Hundred Iterations, Test Accuracy:0.89
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.9
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [11, 24, 31, 39, 45, 51, 64, 82, 83, 89]
# Before Fine-tune, Test Accuracy: 0.01
# After One Hundred Iterations, Test Accuracy:0.91
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.9
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [12, 21, 37, 46, 50, 57, 74, 75, 83, 97]
# Before Fine-tune, Test Accuracy: 0.005
# After One Hundred Iterations, Test Accuracy:0.915
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.9
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [17, 20, 35, 46, 53, 63, 64, 69, 87, 93]
# Before Fine-tune, Test Accuracy: 0.02
# After One Hundred Iterations, Test Accuracy:0.875
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.9
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [0, 2, 5, 13, 25, 40, 62, 68, 90, 95]
# Before Fine-tune, Test Accuracy: 0.025
# After One Hundred Iterations, Test Accuracy:0.895
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.9
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [0, 21, 25, 28, 36, 49, 54, 75, 90, 95]
# Before Fine-tune, Test Accuracy: 0.005
# After One Hundred Iterations, Test Accuracy:0.93
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.9
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [2, 18, 23, 34, 49, 57, 65, 71, 72, 86]
# Before Fine-tune, Test Accuracy: 0.015
# After One Hundred Iterations, Test Accuracy:0.9
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.9
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [7, 8, 18, 23, 35, 38, 48, 63, 75, 77]
# Before Fine-tune, Test Accuracy: 0.005
# After One Hundred Iterations, Test Accuracy:0.91
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.9
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [2, 6, 36, 37, 39, 47, 50, 63, 93, 96]
# Before Fine-tune, Test Accuracy: 0.015
# After One Hundred Iterations, Test Accuracy:0.91
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.9
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [4, 42, 55, 62, 68, 71, 79, 84, 85, 98]
# Before Fine-tune, Test Accuracy: 0.01
# After One Hundred Iterations, Test Accuracy:0.885
# ----------------------------------------------------------------------------------------------
# AVERAGE ACCURACY:  0.8973000049591064

# %%
prune_ratio = 0.95
average = 0
for i in range(50):
    # test_classes = np.random.randint(100,size=10)
    # test_classes = test_classes.tolist()
    test_classes = random.sample(range(0,100),10);
    test_images, test_labels = data_loader.test.next_batch_without_onehot(200)
    test_labels = modify_label(test_labels, test_classes = test_classes)
    print("----------------------------------------------------------------------------------------------")
    model = FineTuneModel(target_class_id = test_classes, prune_ratio=prune_ratio)
    model.assign_weight()
    tmp = model.test_accuracy(test_images, test_labels)
    print("Class: ", test_classes)
    print("Before Fine-tune, Test Accuracy: " + str(tmp))
    for j in range(100):
        train_images, train_labels = data_loader.train.next_batch_without_onehot(500)
        train_labels = modify_label(train_labels, test_classes = test_classes)
        model.train_model(train_images, train_labels)
        accuracy = model.test_accuracy(test_images, test_labels)
        if (j == 99):
            print("After One Hundred Iterations, Test Accuracy:" + str(accuracy))
            average += accuracy
    print("----------------------------------------------------------------------------------------------")
print("AVERAGE ACCURACY: ",str(average*1.0/50))
# Out:
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.95
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [5, 19, 36, 40, 44, 50, 62, 71, 79, 91]
# Before Fine-tune, Test Accuracy: 0.0
# After One Hundred Iterations, Test Accuracy:0.93
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.95
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [14, 16, 19, 20, 31, 35, 72, 78, 86, 99]
# Before Fine-tune, Test Accuracy: 0.005
# After One Hundred Iterations, Test Accuracy:0.9
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.95
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [10, 41, 49, 53, 63, 64, 74, 75, 84, 86]
# Before Fine-tune, Test Accuracy: 0.91
# After One Hundred Iterations, Test Accuracy:0.91
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.95
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [2, 5, 6, 11, 46, 58, 79, 80, 89, 97]
# Before Fine-tune, Test Accuracy: 0.0
# After One Hundred Iterations, Test Accuracy:0.93
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.95
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [7, 13, 14, 25, 44, 50, 53, 67, 69, 73]
# Before Fine-tune, Test Accuracy: 0.005
# After One Hundred Iterations, Test Accuracy:0.915
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.95
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [2, 4, 11, 15, 28, 58, 64, 66, 78, 89]
# Before Fine-tune, Test Accuracy: 0.005
# After One Hundred Iterations, Test Accuracy:0.905
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.95
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [1, 21, 29, 48, 52, 53, 55, 56, 74, 80]
# Before Fine-tune, Test Accuracy: 0.01
# After One Hundred Iterations, Test Accuracy:0.94
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.95
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [3, 21, 33, 35, 42, 44, 48, 61, 66, 96]
# Before Fine-tune, Test Accuracy: 0.005
# After One Hundred Iterations, Test Accuracy:0.91
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.95
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [1, 7, 11, 32, 39, 52, 61, 73, 88, 89]
# Before Fine-tune, Test Accuracy: 0.005
# After One Hundred Iterations, Test Accuracy:0.91
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.95
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [6, 34, 37, 41, 42, 45, 48, 71, 73, 75]
# Before Fine-tune, Test Accuracy: 0.015
# After One Hundred Iterations, Test Accuracy:0.925
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.95
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [5, 7, 13, 17, 45, 54, 70, 88, 89, 94]
# Before Fine-tune, Test Accuracy: 0.01
# After One Hundred Iterations, Test Accuracy:0.92
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.95
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [0, 23, 31, 39, 45, 52, 57, 59, 61, 68]
# Before Fine-tune, Test Accuracy: 0.88
# After One Hundred Iterations, Test Accuracy:0.88
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.95
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [1, 15, 24, 26, 27, 33, 34, 49, 67, 70]
# Before Fine-tune, Test Accuracy: 0.885
# After One Hundred Iterations, Test Accuracy:0.885
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.95
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [4, 10, 20, 41, 48, 49, 70, 85, 88, 89]
# Before Fine-tune, Test Accuracy: 0.0
# After One Hundred Iterations, Test Accuracy:0.86
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.95
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [8, 10, 20, 24, 43, 51, 62, 67, 80, 81]
# Before Fine-tune, Test Accuracy: 0.0
# After One Hundred Iterations, Test Accuracy:0.93
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.95
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [2, 10, 22, 23, 30, 35, 46, 78, 82, 90]
# Before Fine-tune, Test Accuracy: 0.01
# After One Hundred Iterations, Test Accuracy:0.895
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.95
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [11, 19, 45, 55, 60, 68, 83, 85, 90, 96]
# Before Fine-tune, Test Accuracy: 0.005
# After One Hundred Iterations, Test Accuracy:0.895
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.95
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [5, 33, 46, 54, 59, 68, 77, 79, 88, 93]
# Before Fine-tune, Test Accuracy: 0.005
# After One Hundred Iterations, Test Accuracy:0.92
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.95
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [14, 20, 26, 32, 35, 42, 50, 71, 78, 79]
# Before Fine-tune, Test Accuracy: 0.01
# After One Hundred Iterations, Test Accuracy:0.92
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.95
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [13, 25, 36, 38, 45, 48, 50, 53, 65, 71]
# Before Fine-tune, Test Accuracy: 0.025
# After One Hundred Iterations, Test Accuracy:0.875
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.95
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [8, 18, 20, 22, 27, 28, 37, 55, 62, 81]
# Before Fine-tune, Test Accuracy: 0.025
# After One Hundred Iterations, Test Accuracy:0.875
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.95
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [11, 15, 22, 56, 59, 65, 71, 77, 79, 80]
# Before Fine-tune, Test Accuracy: 0.01
# After One Hundred Iterations, Test Accuracy:0.905
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.95
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [1, 5, 6, 10, 20, 30, 35, 50, 78, 94]
# Before Fine-tune, Test Accuracy: 0.89
# After One Hundred Iterations, Test Accuracy:0.89
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.95
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [2, 7, 17, 29, 30, 35, 52, 60, 66, 70]
# Before Fine-tune, Test Accuracy: 0.89
# After One Hundred Iterations, Test Accuracy:0.89
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.95
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [3, 5, 13, 18, 20, 35, 41, 42, 50, 96]
# Before Fine-tune, Test Accuracy: 0.015
# After One Hundred Iterations, Test Accuracy:0.92
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.95
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [12, 17, 47, 60, 66, 74, 78, 86, 89, 91]
# Before Fine-tune, Test Accuracy: 0.005
# After One Hundred Iterations, Test Accuracy:0.85
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.95
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [11, 16, 20, 26, 35, 45, 50, 69, 75, 89]
# Before Fine-tune, Test Accuracy: 0.0
# After One Hundred Iterations, Test Accuracy:0.895
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.95
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [11, 13, 15, 21, 32, 48, 68, 72, 76, 85]
# Before Fine-tune, Test Accuracy: 0.01
# After One Hundred Iterations, Test Accuracy:0.88
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.95
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [0, 3, 45, 52, 54, 59, 69, 87, 98, 99]
# Before Fine-tune, Test Accuracy: 0.01
# After One Hundred Iterations, Test Accuracy:0.895
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.95
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [4, 6, 10, 17, 22, 26, 47, 66, 90, 97]
# Before Fine-tune, Test Accuracy: 0.005
# After One Hundred Iterations, Test Accuracy:0.905
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.95
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [20, 39, 41, 46, 52, 58, 63, 78, 83, 99]
# Before Fine-tune, Test Accuracy: 0.885
# After One Hundred Iterations, Test Accuracy:0.885
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.95
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [2, 5, 34, 41, 58, 63, 77, 86, 92, 96]
# Before Fine-tune, Test Accuracy: 0.0
# After One Hundred Iterations, Test Accuracy:0.905
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.95
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [6, 8, 24, 48, 57, 68, 81, 86, 92, 96]
# Before Fine-tune, Test Accuracy: 0.005
# After One Hundred Iterations, Test Accuracy:0.895
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.95
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [7, 12, 18, 31, 57, 60, 71, 85, 96, 99]
# Before Fine-tune, Test Accuracy: 0.005
# After One Hundred Iterations, Test Accuracy:0.935
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.95
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [7, 17, 20, 22, 31, 60, 61, 68, 72, 95]
# Before Fine-tune, Test Accuracy: 0.015
# After One Hundred Iterations, Test Accuracy:0.895
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.95
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [3, 8, 12, 13, 31, 32, 67, 68, 80, 81]
# Before Fine-tune, Test Accuracy: 0.0
# After One Hundred Iterations, Test Accuracy:0.915
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.95
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [13, 31, 41, 50, 56, 57, 66, 75, 84, 91]
# Before Fine-tune, Test Accuracy: 0.005
# After One Hundred Iterations, Test Accuracy:0.935
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.95
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [13, 21, 25, 38, 47, 54, 56, 57, 58, 65]
# Before Fine-tune, Test Accuracy: 0.92
# After One Hundred Iterations, Test Accuracy:0.92
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.95
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [0, 6, 22, 25, 35, 42, 54, 61, 67, 69]
# Before Fine-tune, Test Accuracy: 0.005
# After One Hundred Iterations, Test Accuracy:0.915
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.95
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [6, 18, 19, 44, 67, 78, 82, 85, 87, 99]
# Before Fine-tune, Test Accuracy: 0.025
# After One Hundred Iterations, Test Accuracy:0.895
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.95
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [1, 13, 41, 42, 60, 70, 79, 85, 90, 97]
# Before Fine-tune, Test Accuracy: 0.88
# After One Hundred Iterations, Test Accuracy:0.88
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.95
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [11, 17, 36, 39, 62, 73, 75, 85, 93, 98]
# Before Fine-tune, Test Accuracy: 0.01
# After One Hundred Iterations, Test Accuracy:0.875
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.95
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [8, 28, 30, 49, 76, 77, 79, 80, 87, 88]
# Before Fine-tune, Test Accuracy: 0.005
# After One Hundred Iterations, Test Accuracy:0.855
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.95
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [5, 18, 27, 34, 47, 60, 70, 71, 86, 99]
# Before Fine-tune, Test Accuracy: 0.03
# After One Hundred Iterations, Test Accuracy:0.875
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.95
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [34, 46, 51, 53, 59, 64, 66, 78, 79, 81]
# Before Fine-tune, Test Accuracy: 0.01
# After One Hundred Iterations, Test Accuracy:0.885
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.95
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [0, 22, 46, 47, 48, 70, 79, 86, 97, 98]
# Before Fine-tune, Test Accuracy: 0.005
# After One Hundred Iterations, Test Accuracy:0.94
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.95
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [5, 18, 21, 30, 34, 35, 42, 57, 72, 85]
# Before Fine-tune, Test Accuracy: 0.015
# After One Hundred Iterations, Test Accuracy:0.9
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.95
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [2, 28, 32, 35, 67, 69, 72, 73, 79, 90]
# Before Fine-tune, Test Accuracy: 0.01
# After One Hundred Iterations, Test Accuracy:0.91
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.95
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [4, 10, 27, 38, 59, 67, 87, 90, 91, 92]
# Before Fine-tune, Test Accuracy: 0.015
# After One Hundred Iterations, Test Accuracy:0.87
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.95
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [5, 15, 24, 27, 28, 66, 68, 76, 89, 91]
# Before Fine-tune, Test Accuracy: 0.905
# After One Hundred Iterations, Test Accuracy:0.905
# ----------------------------------------------------------------------------------------------
# AVERAGE ACCURACY:  0.9009999990463257

# %%
prune_ratio = 0.99
average = 0
for i in range(50):
    # test_classes = np.random.randint(100,size=10)
    # test_classes = test_classes.tolist()
    test_classes = random.sample(range(0,100),10);
    test_images, test_labels = data_loader.test.next_batch_without_onehot(200)
    test_labels = modify_label(test_labels, test_classes = test_classes)
    print("----------------------------------------------------------------------------------------------")
    model = FineTuneModel(target_class_id = test_classes, prune_ratio=prune_ratio)
    model.assign_weight()
    tmp = model.test_accuracy(test_images, test_labels)
    print("Class: ", test_classes)
    print("Before Fine-tune, Test Accuracy: " + str(tmp))
    for j in range(100):
        train_images, train_labels = data_loader.train.next_batch_without_onehot(500)
        train_labels = modify_label(train_labels, test_classes = test_classes)
        model.train_model(train_images, train_labels)
        accuracy = model.test_accuracy(test_images, test_labels)
        if (j == 99):
            print("After One Hundred Iterations, Test Accuracy:" + str(accuracy))
            average += accuracy
    print("----------------------------------------------------------------------------------------------")
print("AVERAGE ACCURACY: ",str(average*1.0/50))
# Out:
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.99
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [1, 25, 35, 44, 45, 48, 72, 77, 80, 85]
# Before Fine-tune, Test Accuracy: 0.0
# After One Hundred Iterations, Test Accuracy:0.93
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.99
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [5, 7, 13, 17, 19, 31, 36, 62, 86, 92]
# Before Fine-tune, Test Accuracy: 0.005
# After One Hundred Iterations, Test Accuracy:0.875
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.99
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [18, 22, 34, 47, 51, 56, 64, 65, 78, 85]
# Before Fine-tune, Test Accuracy: 0.01
# After One Hundred Iterations, Test Accuracy:0.905
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.99
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [16, 17, 18, 43, 44, 73, 79, 81, 86, 94]
# Before Fine-tune, Test Accuracy: 0.0
# After One Hundred Iterations, Test Accuracy:0.91
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.99
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [16, 23, 27, 35, 40, 51, 67, 79, 82, 86]
# Before Fine-tune, Test Accuracy: 0.015
# After One Hundred Iterations, Test Accuracy:0.91
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.99
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [8, 17, 40, 58, 61, 65, 75, 76, 83, 87]
# Before Fine-tune, Test Accuracy: 0.015
# After One Hundred Iterations, Test Accuracy:0.925
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.99
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [5, 14, 15, 20, 45, 61, 65, 74, 82, 92]
# Before Fine-tune, Test Accuracy: 0.02
# After One Hundred Iterations, Test Accuracy:0.89
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.99
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [33, 51, 61, 65, 68, 71, 76, 83, 88, 95]
# Before Fine-tune, Test Accuracy: 0.01
# After One Hundred Iterations, Test Accuracy:0.92
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.99
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [36, 39, 63, 65, 66, 77, 83, 85, 96, 97]
# Before Fine-tune, Test Accuracy: 0.935
# After One Hundred Iterations, Test Accuracy:0.935
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.99
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [5, 29, 40, 41, 52, 54, 74, 76, 84, 93]
# Before Fine-tune, Test Accuracy: 0.005
# After One Hundred Iterations, Test Accuracy:0.915
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.99
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [10, 12, 15, 32, 36, 49, 50, 68, 81, 84]
# Before Fine-tune, Test Accuracy: 0.015
# After One Hundred Iterations, Test Accuracy:0.895
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.99
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [2, 4, 51, 60, 61, 62, 66, 73, 83, 96]
# Before Fine-tune, Test Accuracy: 0.015
# After One Hundred Iterations, Test Accuracy:0.865
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.99
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [0, 2, 16, 26, 27, 34, 49, 68, 75, 85]
# Before Fine-tune, Test Accuracy: 0.02
# After One Hundred Iterations, Test Accuracy:0.89
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.99
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [2, 8, 14, 28, 33, 57, 62, 74, 84, 89]
# Before Fine-tune, Test Accuracy: 0.02
# After One Hundred Iterations, Test Accuracy:0.93
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.99
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [2, 4, 7, 11, 16, 19, 23, 45, 59, 86]
# Before Fine-tune, Test Accuracy: 0.005
# After One Hundred Iterations, Test Accuracy:0.89
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.99
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [8, 10, 11, 13, 23, 51, 70, 72, 73, 99]
# Before Fine-tune, Test Accuracy: 0.005
# After One Hundred Iterations, Test Accuracy:0.9
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.99
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [12, 16, 19, 25, 33, 56, 59, 76, 80, 92]
# Before Fine-tune, Test Accuracy: 0.005
# After One Hundred Iterations, Test Accuracy:0.915
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.99
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [18, 39, 47, 50, 69, 71, 77, 82, 86, 89]
# Before Fine-tune, Test Accuracy: 0.015
# After One Hundred Iterations, Test Accuracy:0.91
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.99
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [5, 6, 7, 33, 49, 55, 58, 66, 84, 86]
# Before Fine-tune, Test Accuracy: 0.025
# After One Hundred Iterations, Test Accuracy:0.875
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.99
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [0, 16, 18, 24, 31, 37, 38, 40, 76, 94]
# Before Fine-tune, Test Accuracy: 0.005
# After One Hundred Iterations, Test Accuracy:0.885
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.99
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [26, 29, 38, 49, 56, 57, 61, 74, 89, 90]
# Before Fine-tune, Test Accuracy: 0.0
# After One Hundred Iterations, Test Accuracy:0.88
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.99
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [8, 21, 22, 25, 30, 61, 75, 76, 80, 82]
# Before Fine-tune, Test Accuracy: 0.005
# After One Hundred Iterations, Test Accuracy:0.885
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.99
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [3, 23, 31, 35, 62, 69, 72, 78, 86, 92]
# Before Fine-tune, Test Accuracy: 0.01
# After One Hundred Iterations, Test Accuracy:0.91
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.99
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [0, 3, 12, 18, 30, 33, 40, 65, 72, 95]
# Before Fine-tune, Test Accuracy: 0.01
# After One Hundred Iterations, Test Accuracy:0.885
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.99
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [1, 11, 18, 25, 28, 35, 57, 70, 74, 86]
# Before Fine-tune, Test Accuracy: 0.015
# After One Hundred Iterations, Test Accuracy:0.91
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.99
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [29, 39, 42, 47, 54, 56, 60, 67, 80, 98]
# Before Fine-tune, Test Accuracy: 0.015
# After One Hundred Iterations, Test Accuracy:0.905
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.99
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [21, 45, 46, 48, 49, 58, 71, 76, 79, 86]
# Before Fine-tune, Test Accuracy: 0.015
# After One Hundred Iterations, Test Accuracy:0.89
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.99
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [3, 17, 36, 38, 39, 46, 50, 59, 61, 95]
# Before Fine-tune, Test Accuracy: 0.925
# After One Hundred Iterations, Test Accuracy:0.925
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.99
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [6, 21, 54, 58, 59, 61, 66, 76, 80, 87]
# Before Fine-tune, Test Accuracy: 0.005
# After One Hundred Iterations, Test Accuracy:0.875
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.99
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [10, 16, 20, 39, 42, 64, 80, 82, 89, 94]
# Before Fine-tune, Test Accuracy: 0.005
# After One Hundred Iterations, Test Accuracy:0.9
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.99
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [9, 21, 27, 40, 51, 52, 54, 60, 79, 83]
# Before Fine-tune, Test Accuracy: 0.0
# After One Hundred Iterations, Test Accuracy:0.915
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.99
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [23, 26, 27, 38, 51, 57, 60, 67, 77, 83]
# Before Fine-tune, Test Accuracy: 0.0
# After One Hundred Iterations, Test Accuracy:0.9
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.99
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [5, 15, 18, 38, 45, 50, 60, 61, 71, 82]
# Before Fine-tune, Test Accuracy: 0.015
# After One Hundred Iterations, Test Accuracy:0.885
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.99
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [3, 4, 23, 24, 30, 34, 46, 59, 81, 97]
# Before Fine-tune, Test Accuracy: 0.01
# After One Hundred Iterations, Test Accuracy:0.89
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.99
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [16, 18, 23, 28, 32, 36, 46, 52, 55, 64]
# Before Fine-tune, Test Accuracy: 0.01
# After One Hundred Iterations, Test Accuracy:0.925
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.99
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [13, 22, 29, 37, 52, 55, 63, 78, 79, 97]
# Before Fine-tune, Test Accuracy: 0.93
# After One Hundred Iterations, Test Accuracy:0.93
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.99
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [12, 15, 16, 20, 22, 29, 41, 49, 87, 92]
# Before Fine-tune, Test Accuracy: 0.005
# After One Hundred Iterations, Test Accuracy:0.89
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.99
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [1, 4, 10, 11, 38, 62, 67, 72, 81, 84]
# Before Fine-tune, Test Accuracy: 0.01
# After One Hundred Iterations, Test Accuracy:0.945
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.99
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [12, 21, 24, 41, 44, 46, 47, 51, 52, 55]
# Before Fine-tune, Test Accuracy: 0.015
# After One Hundred Iterations, Test Accuracy:0.895
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.99
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [8, 9, 11, 12, 19, 25, 30, 50, 54, 95]
# Before Fine-tune, Test Accuracy: 0.015
# After One Hundred Iterations, Test Accuracy:0.905
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.99
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [6, 9, 18, 27, 46, 54, 65, 73, 75, 95]
# Before Fine-tune, Test Accuracy: 0.02
# After One Hundred Iterations, Test Accuracy:0.885
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.99
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [9, 11, 13, 31, 33, 38, 40, 41, 78, 82]
# Before Fine-tune, Test Accuracy: 0.905
# After One Hundred Iterations, Test Accuracy:0.905
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.99
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [4, 5, 16, 35, 37, 49, 67, 73, 82, 91]
# Before Fine-tune, Test Accuracy: 0.89
# After One Hundred Iterations, Test Accuracy:0.89
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.99
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [1, 15, 16, 20, 23, 28, 49, 76, 84, 87]
# Before Fine-tune, Test Accuracy: 0.015
# After One Hundred Iterations, Test Accuracy:0.86
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.99
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [1, 4, 11, 29, 31, 45, 74, 86, 89, 90]
# Before Fine-tune, Test Accuracy: 0.005
# After One Hundred Iterations, Test Accuracy:0.895
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.99
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [1, 6, 13, 22, 39, 62, 65, 86, 96, 99]
# Before Fine-tune, Test Accuracy: 0.015
# After One Hundred Iterations, Test Accuracy:0.93
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.99
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [5, 7, 8, 15, 32, 33, 45, 59, 77, 85]
# Before Fine-tune, Test Accuracy: 0.02
# After One Hundred Iterations, Test Accuracy:0.88
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.99
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [4, 14, 25, 29, 40, 46, 56, 71, 80, 98]
# Before Fine-tune, Test Accuracy: 0.015
# After One Hundred Iterations, Test Accuracy:0.89
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.99
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [0, 21, 29, 33, 38, 41, 74, 84, 87, 95]
# Before Fine-tune, Test Accuracy: 0.005
# After One Hundred Iterations, Test Accuracy:0.9
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# Prune Ratio: 0.99
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [5, 7, 12, 25, 28, 47, 54, 63, 96, 98]
# Before Fine-tune, Test Accuracy: 0.005
# After One Hundred Iterations, Test Accuracy:0.945
# ----------------------------------------------------------------------------------------------
# AVERAGE ACCURACY:  0.9018999969959259
