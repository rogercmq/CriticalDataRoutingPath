# %%
from vggFinetuneModel import FineTuneModel
from CIFAR_DataLoader import CifarDataManager
import numpy as np
# Out:
# Using TensorFlow backend.

# %%
def one_hot(vec, vals=10):
    n = len(vec)
    out = np.zeros((n, vals))
    out[range(n), vec] = 1
    return out

def modify_label(labels, test_classes = [0]):
    test_classes.sort()
    tmp_labels = []
    for i in labels:
        if i in test_classes:
            tmp_labels.append(test_classes.index(i))
        else:
            tmp_labels.append(len(test_classes))
    return one_hot(tmp_labels, vals=len(test_classes)+1)

# %%
data_loader = CifarDataManager()

# %% [markdown]
# ## 统计multi-class的accuracy平均数, num of classes:25

# %%
average = 0
for i in range(50):
    test_classes = np.random.randint(100,size=25)
    test_classes = test_classes.tolist()
    test_images, test_labels = data_loader.test.next_batch_without_onehot(200)
    test_labels = modify_label(test_labels, test_classes = test_classes)
    print("----------------------------------------------------------------------------------------------")
    model = FineTuneModel(target_class_id = test_classes)
    model.assign_weight()
    tmp = model.test_accuracy(test_images, test_labels)
    print("Class: ", test_classes)
    print("Before Fine-tune, Test Accuracy: " + str(tmp))
    for j in range(100):
        train_images, train_labels = data_loader.train.next_batch_without_onehot(500)
        train_labels = modify_label(train_labels, test_classes = test_classes)
        model.train_model(train_images, train_labels)
        accuracy = model.test_accuracy(test_images, test_labels)
        if (j == 99):
            print("After One Hundred Iterations, Test Accuracy:" + str(accuracy))
            average += accuracy
    print("----------------------------------------------------------------------------------------------")
print("AVERAGE ACCURACY: ",str(average*1.0/50))
# Out:
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [4, 5, 7, 10, 12, 19, 22, 29, 35, 37, 39, 41, 41, 45, 49, 64, 70, 74, 74, 77, 78, 85, 94, 98, 99]
# Before Fine-tune, Test Accuracy: 0.015
# After One Hundred Iterations, Test Accuracy:0.755
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [1, 2, 4, 16, 27, 32, 36, 39, 39, 43, 45, 47, 49, 53, 55, 62, 65, 68, 74, 79, 79, 80, 84, 85, 96]
# Before Fine-tune, Test Accuracy: 0.015
# After One Hundred Iterations, Test Accuracy:0.76
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [2, 4, 13, 15, 22, 22, 22, 25, 35, 39, 43, 44, 46, 52, 67, 69, 71, 72, 76, 78, 83, 84, 91, 91, 92]
# Before Fine-tune, Test Accuracy: 0.005
# After One Hundred Iterations, Test Accuracy:0.79
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [4, 4, 5, 9, 16, 16, 16, 27, 31, 37, 40, 43, 45, 49, 52, 56, 58, 59, 72, 72, 79, 80, 87, 94, 97]
# Before Fine-tune, Test Accuracy: 0.0
# After One Hundred Iterations, Test Accuracy:0.86
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [0, 1, 1, 5, 5, 7, 9, 17, 17, 20, 34, 40, 43, 47, 71, 73, 76, 85, 89, 90, 93, 96, 96, 99, 99]
# Before Fine-tune, Test Accuracy: 0.0
# After One Hundred Iterations, Test Accuracy:0.8
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [2, 5, 7, 9, 12, 16, 30, 31, 33, 38, 40, 40, 44, 46, 48, 50, 54, 65, 66, 67, 68, 86, 89, 92, 99]
# Before Fine-tune, Test Accuracy: 0.005
# After One Hundred Iterations, Test Accuracy:0.765
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [0, 8, 12, 27, 34, 35, 40, 42, 45, 48, 48, 51, 55, 64, 65, 72, 73, 81, 83, 83, 85, 89, 90, 93, 97]
# Before Fine-tune, Test Accuracy: 0.015
# After One Hundred Iterations, Test Accuracy:0.77
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [5, 11, 13, 16, 16, 22, 28, 34, 39, 43, 46, 53, 54, 54, 55, 66, 77, 82, 83, 84, 89, 90, 90, 97, 97]
# Before Fine-tune, Test Accuracy: 0.02
# After One Hundred Iterations, Test Accuracy:0.735
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [1, 1, 5, 12, 14, 18, 20, 20, 21, 22, 23, 26, 30, 31, 33, 39, 42, 64, 66, 74, 74, 86, 90, 90, 96]
# Before Fine-tune, Test Accuracy: 0.005
# After One Hundred Iterations, Test Accuracy:0.77
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [1, 1, 7, 9, 16, 27, 31, 32, 35, 40, 43, 44, 44, 55, 55, 57, 57, 64, 65, 66, 78, 79, 87, 90, 97]
# Before Fine-tune, Test Accuracy: 0.01
# After One Hundred Iterations, Test Accuracy:0.815
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [0, 6, 6, 12, 21, 22, 27, 27, 29, 31, 32, 35, 37, 40, 45, 58, 60, 63, 64, 67, 73, 79, 85, 98, 99]
# Before Fine-tune, Test Accuracy: 0.01
# After One Hundred Iterations, Test Accuracy:0.75
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [7, 23, 27, 28, 32, 35, 36, 43, 49, 53, 55, 55, 60, 60, 62, 65, 71, 80, 85, 86, 89, 93, 95, 95, 96]
# Before Fine-tune, Test Accuracy: 0.01
# After One Hundred Iterations, Test Accuracy:0.83
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [5, 8, 9, 15, 16, 17, 22, 23, 25, 29, 31, 39, 41, 47, 58, 59, 61, 61, 72, 73, 81, 82, 86, 91, 93]
# Before Fine-tune, Test Accuracy: 0.005
# After One Hundred Iterations, Test Accuracy:0.71
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [1, 4, 17, 24, 33, 34, 44, 44, 46, 47, 53, 55, 57, 58, 67, 68, 69, 76, 78, 78, 84, 90, 92, 94, 95]
# Before Fine-tune, Test Accuracy: 0.0
# After One Hundred Iterations, Test Accuracy:0.775
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [5, 7, 15, 16, 20, 22, 24, 25, 28, 48, 48, 48, 52, 54, 55, 60, 66, 72, 77, 79, 89, 91, 97, 97, 99]
# Before Fine-tune, Test Accuracy: 0.0
# After One Hundred Iterations, Test Accuracy:0.785
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [0, 4, 5, 19, 21, 25, 27, 28, 29, 33, 38, 41, 44, 50, 51, 52, 64, 67, 73, 77, 81, 87, 94, 97, 99]
# Before Fine-tune, Test Accuracy: 0.01
# After One Hundred Iterations, Test Accuracy:0.76
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [5, 6, 6, 8, 19, 19, 22, 29, 36, 38, 40, 44, 48, 52, 62, 63, 68, 70, 74, 76, 79, 84, 93, 96, 98]
# Before Fine-tune, Test Accuracy: 0.015
# After One Hundred Iterations, Test Accuracy:0.755
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [0, 2, 8, 8, 11, 14, 15, 21, 34, 39, 40, 41, 44, 54, 54, 63, 64, 66, 68, 72, 76, 77, 78, 91, 99]
# Before Fine-tune, Test Accuracy: 0.015
# After One Hundred Iterations, Test Accuracy:0.795
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [1, 7, 21, 22, 39, 44, 45, 46, 51, 51, 54, 55, 56, 60, 62, 69, 73, 74, 83, 87, 87, 89, 90, 91, 96]
# Before Fine-tune, Test Accuracy: 0.0
# After One Hundred Iterations, Test Accuracy:0.77
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [1, 2, 7, 8, 18, 20, 22, 26, 30, 30, 31, 33, 40, 64, 65, 65, 77, 79, 83, 85, 87, 91, 91, 98, 98]
# Before Fine-tune, Test Accuracy: 0.78
# After One Hundred Iterations, Test Accuracy:0.78
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [0, 9, 10, 13, 20, 24, 24, 33, 35, 45, 46, 48, 52, 54, 57, 59, 68, 78, 81, 89, 90, 96, 96, 97, 97]
# Before Fine-tune, Test Accuracy: 0.0
# After One Hundred Iterations, Test Accuracy:0.77
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [1, 2, 12, 13, 13, 16, 17, 22, 32, 35, 39, 51, 57, 74, 78, 78, 80, 81, 83, 83, 85, 86, 89, 92, 97]
# Before Fine-tune, Test Accuracy: 0.005
# After One Hundred Iterations, Test Accuracy:0.8
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [0, 2, 3, 13, 16, 24, 29, 34, 46, 46, 49, 56, 58, 65, 67, 69, 71, 74, 74, 77, 77, 80, 82, 85, 90]
# Before Fine-tune, Test Accuracy: 0.005
# After One Hundred Iterations, Test Accuracy:0.78
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [1, 2, 4, 4, 7, 23, 24, 26, 27, 29, 31, 39, 44, 55, 63, 66, 69, 80, 81, 86, 86, 91, 91, 96, 99]
# Before Fine-tune, Test Accuracy: 0.015
# After One Hundred Iterations, Test Accuracy:0.765
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [6, 15, 16, 22, 23, 29, 34, 40, 45, 46, 50, 53, 55, 61, 62, 62, 70, 74, 76, 81, 83, 89, 93, 96, 98]
# Before Fine-tune, Test Accuracy: 0.0
# After One Hundred Iterations, Test Accuracy:0.765
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [0, 3, 10, 14, 15, 18, 23, 30, 35, 43, 50, 52, 52, 53, 62, 66, 71, 73, 81, 82, 85, 95, 96, 97, 99]
# Before Fine-tune, Test Accuracy: 0.01
# After One Hundred Iterations, Test Accuracy:0.755
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [4, 8, 25, 30, 34, 37, 43, 46, 54, 55, 64, 67, 67, 67, 67, 72, 72, 77, 81, 89, 89, 91, 93, 96, 97]
# Before Fine-tune, Test Accuracy: 0.03
# After One Hundred Iterations, Test Accuracy:0.805
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [1, 4, 8, 10, 15, 17, 17, 20, 23, 28, 36, 39, 39, 41, 42, 57, 58, 60, 66, 71, 74, 74, 87, 91, 92]
# Before Fine-tune, Test Accuracy: 0.0
# After One Hundred Iterations, Test Accuracy:0.755
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [5, 8, 18, 18, 27, 29, 30, 33, 33, 38, 38, 44, 47, 49, 59, 64, 71, 73, 82, 91, 94, 96, 98, 98, 99]
# Before Fine-tune, Test Accuracy: 0.005
# After One Hundred Iterations, Test Accuracy:0.81
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [0, 2, 3, 8, 9, 11, 11, 13, 15, 23, 24, 29, 43, 57, 76, 76, 85, 90, 91, 93, 93, 93, 97, 97, 99]
# Before Fine-tune, Test Accuracy: 0.005
# After One Hundred Iterations, Test Accuracy:0.8
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [5, 10, 10, 11, 19, 19, 20, 24, 25, 44, 46, 46, 46, 50, 51, 53, 55, 55, 55, 57, 61, 72, 73, 76, 78]
# Before Fine-tune, Test Accuracy: 0.01
# After One Hundred Iterations, Test Accuracy:0.83
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [0, 0, 2, 3, 6, 11, 12, 13, 18, 21, 23, 26, 44, 46, 47, 50, 63, 64, 69, 74, 86, 88, 91, 91, 98]
# Before Fine-tune, Test Accuracy: 0.005
# After One Hundred Iterations, Test Accuracy:0.735
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [2, 4, 6, 9, 12, 14, 30, 35, 39, 39, 50, 52, 63, 64, 73, 75, 77, 77, 78, 83, 86, 87, 87, 90, 97]
# Before Fine-tune, Test Accuracy: 0.01
# After One Hundred Iterations, Test Accuracy:0.8
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [1, 6, 23, 25, 25, 30, 30, 42, 43, 48, 49, 51, 52, 52, 54, 56, 59, 61, 74, 85, 86, 90, 92, 94, 95]
# Before Fine-tune, Test Accuracy: 0.01
# After One Hundred Iterations, Test Accuracy:0.795
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [0, 4, 5, 27, 41, 47, 50, 52, 52, 54, 59, 61, 62, 64, 69, 72, 73, 74, 77, 79, 81, 81, 83, 95, 97]
# Before Fine-tune, Test Accuracy: 0.005
# After One Hundred Iterations, Test Accuracy:0.8
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [0, 7, 10, 15, 16, 17, 17, 18, 22, 33, 35, 38, 42, 46, 64, 70, 71, 72, 74, 77, 78, 88, 89, 91, 98]
# Before Fine-tune, Test Accuracy: 0.245
# After One Hundred Iterations, Test Accuracy:0.79
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [3, 7, 7, 7, 9, 9, 10, 21, 31, 36, 37, 40, 44, 46, 61, 63, 73, 76, 81, 82, 86, 87, 97, 98, 99]
# Before Fine-tune, Test Accuracy: 0.02
# After One Hundred Iterations, Test Accuracy:0.82
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [4, 6, 7, 9, 13, 19, 33, 38, 45, 48, 56, 62, 62, 63, 65, 74, 86, 88, 88, 89, 89, 90, 93, 94, 98]
# Before Fine-tune, Test Accuracy: 0.005
# After One Hundred Iterations, Test Accuracy:0.735
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [6, 14, 15, 18, 24, 24, 27, 30, 31, 38, 39, 42, 47, 54, 54, 56, 58, 63, 66, 68, 69, 76, 76, 78, 82]
# Before Fine-tune, Test Accuracy: 0.005
# After One Hundred Iterations, Test Accuracy:0.815
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [3, 6, 10, 10, 11, 13, 21, 23, 33, 39, 44, 52, 56, 57, 57, 58, 65, 67, 70, 71, 72, 95, 96, 98, 98]
# Before Fine-tune, Test Accuracy: 0.01
# After One Hundred Iterations, Test Accuracy:0.8
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [4, 5, 6, 7, 7, 13, 30, 31, 33, 35, 38, 40, 42, 43, 43, 53, 54, 57, 57, 59, 63, 73, 74, 77, 99]
# Before Fine-tune, Test Accuracy: 0.01
# After One Hundred Iterations, Test Accuracy:0.765
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [6, 10, 11, 13, 17, 25, 34, 36, 41, 47, 53, 53, 59, 59, 62, 64, 65, 70, 74, 78, 79, 80, 84, 93, 94]
# Before Fine-tune, Test Accuracy: 0.0
# After One Hundred Iterations, Test Accuracy:0.795
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [4, 5, 23, 24, 25, 33, 40, 40, 47, 55, 55, 56, 60, 64, 65, 69, 70, 74, 75, 81, 92, 92, 95, 96, 99]
# Before Fine-tune, Test Accuracy: 0.01
# After One Hundred Iterations, Test Accuracy:0.76
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [1, 12, 19, 19, 23, 25, 41, 43, 43, 43, 45, 45, 47, 52, 56, 58, 63, 64, 66, 71, 75, 83, 87, 90, 96]
# Before Fine-tune, Test Accuracy: 0.015
# After One Hundred Iterations, Test Accuracy:0.79
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [3, 9, 13, 15, 20, 24, 26, 29, 37, 37, 38, 38, 39, 44, 44, 48, 53, 57, 68, 80, 85, 89, 89, 93, 96]
# Before Fine-tune, Test Accuracy: 0.0
# After One Hundred Iterations, Test Accuracy:0.785
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [6, 16, 17, 24, 27, 41, 41, 46, 48, 50, 56, 58, 62, 64, 68, 71, 72, 72, 75, 82, 86, 94, 96, 97, 99]
# Before Fine-tune, Test Accuracy: 0.0
# After One Hundred Iterations, Test Accuracy:0.8
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [3, 3, 13, 13, 20, 21, 28, 34, 43, 45, 48, 51, 53, 53, 54, 61, 64, 74, 78, 86, 86, 86, 88, 91, 99]
# Before Fine-tune, Test Accuracy: 0.0
# After One Hundred Iterations, Test Accuracy:0.83
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [7, 13, 15, 17, 21, 23, 24, 28, 30, 43, 46, 50, 56, 60, 64, 67, 71, 71, 80, 81, 85, 87, 90, 93, 98]
# Before Fine-tune, Test Accuracy: 0.025
# After One Hundred Iterations, Test Accuracy:0.695
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [3, 12, 13, 15, 15, 19, 22, 32, 33, 36, 38, 47, 51, 53, 54, 54, 56, 67, 69, 73, 78, 85, 89, 93, 96]
# Before Fine-tune, Test Accuracy: 0.02
# After One Hundred Iterations, Test Accuracy:0.74
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [3, 8, 13, 15, 19, 21, 27, 33, 33, 34, 36, 37, 40, 46, 47, 48, 51, 51, 55, 58, 61, 65, 79, 79, 97]
# Before Fine-tune, Test Accuracy: 0.015
# After One Hundred Iterations, Test Accuracy:0.785
# ----------------------------------------------------------------------------------------------
# AVERAGE ACCURACY:  0.78

# %% [markdown]
# ## 统计multi-class的accuracy平均数, num of classes:10

# %%
average = 0
for i in range(50):
    test_classes = np.random.randint(100,size=10)
    test_classes = test_classes.tolist()
    test_images, test_labels = data_loader.test.next_batch_without_onehot(200)
    test_labels = modify_label(test_labels, test_classes = test_classes)
    print("----------------------------------------------------------------------------------------------")
    model = FineTuneModel(target_class_id = test_classes)
    model.assign_weight()
    tmp = model.test_accuracy(test_images, test_labels)
    print("Class: ", test_classes)
    print("Before Fine-tune, Test Accuracy: " + str(tmp))
    for j in range(100):
        train_images, train_labels = data_loader.train.next_batch_without_onehot(500)
        train_labels = modify_label(train_labels, test_classes = test_classes)
        model.train_model(train_images, train_labels)
        accuracy = model.test_accuracy(test_images, test_labels)
        if (j == 99):
            print("After One Hundred Iterations, Test Accuracy:" + str(accuracy))
            average += accuracy
    print("----------------------------------------------------------------------------------------------")
print("AVERAGE ACCURACY: ",str(average*1.0/50))
# Out:
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [0, 7, 38, 43, 44, 47, 49, 49, 74, 97]
# Before Fine-tune, Test Accuracy: 0.02
# After One Hundred Iterations, Test Accuracy:0.925
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [0, 10, 18, 25, 31, 48, 52, 56, 70, 80]
# Before Fine-tune, Test Accuracy: 0.0
# After One Hundred Iterations, Test Accuracy:0.885
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [0, 8, 30, 32, 34, 43, 55, 56, 74, 84]
# Before Fine-tune, Test Accuracy: 0.01
# After One Hundred Iterations, Test Accuracy:0.915
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [6, 11, 35, 42, 49, 53, 65, 75, 85, 98]
# Before Fine-tune, Test Accuracy: 0.935
# After One Hundred Iterations, Test Accuracy:0.935
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [3, 7, 9, 23, 31, 41, 44, 69, 80, 93]
# Before Fine-tune, Test Accuracy: 0.905
# After One Hundred Iterations, Test Accuracy:0.905
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [0, 5, 16, 40, 40, 63, 67, 69, 74, 76]
# Before Fine-tune, Test Accuracy: 0.905
# After One Hundred Iterations, Test Accuracy:0.905
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [2, 13, 14, 33, 58, 62, 73, 76, 80, 82]
# Before Fine-tune, Test Accuracy: 0.0
# After One Hundred Iterations, Test Accuracy:0.945
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [9, 35, 49, 50, 53, 53, 54, 77, 89, 93]
# Before Fine-tune, Test Accuracy: 0.0
# After One Hundred Iterations, Test Accuracy:0.92
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [4, 6, 12, 33, 35, 42, 44, 61, 77, 79]
# Before Fine-tune, Test Accuracy: 0.89
# After One Hundred Iterations, Test Accuracy:0.89
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [6, 9, 15, 19, 40, 40, 53, 54, 74, 83]
# Before Fine-tune, Test Accuracy: 0.01
# After One Hundred Iterations, Test Accuracy:0.905
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [1, 27, 53, 57, 58, 63, 83, 83, 97, 99]
# Before Fine-tune, Test Accuracy: 0.005
# After One Hundred Iterations, Test Accuracy:0.895
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [23, 47, 55, 57, 61, 62, 69, 77, 84, 96]
# Before Fine-tune, Test Accuracy: 0.015
# After One Hundred Iterations, Test Accuracy:0.88
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [14, 27, 32, 33, 49, 58, 69, 73, 94, 97]
# Before Fine-tune, Test Accuracy: 0.005
# After One Hundred Iterations, Test Accuracy:0.895
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [6, 12, 14, 17, 19, 19, 50, 55, 91, 94]
# Before Fine-tune, Test Accuracy: 0.005
# After One Hundred Iterations, Test Accuracy:0.92
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [6, 22, 33, 38, 50, 60, 63, 71, 71, 92]
# Before Fine-tune, Test Accuracy: 0.015
# After One Hundred Iterations, Test Accuracy:0.9
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [10, 10, 29, 36, 57, 64, 79, 89, 91, 94]
# Before Fine-tune, Test Accuracy: 0.015
# After One Hundred Iterations, Test Accuracy:0.915
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [2, 4, 7, 14, 18, 30, 71, 77, 79, 93]
# Before Fine-tune, Test Accuracy: 0.02
# After One Hundred Iterations, Test Accuracy:0.88
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [6, 14, 30, 34, 37, 39, 56, 58, 94, 99]
# Before Fine-tune, Test Accuracy: 0.015
# After One Hundred Iterations, Test Accuracy:0.925
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [18, 35, 51, 52, 54, 57, 59, 73, 77, 81]
# Before Fine-tune, Test Accuracy: 0.015
# After One Hundred Iterations, Test Accuracy:0.885
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [26, 26, 39, 41, 62, 63, 63, 64, 67, 73]
# Before Fine-tune, Test Accuracy: 0.0
# After One Hundred Iterations, Test Accuracy:0.89
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [25, 41, 48, 50, 52, 74, 82, 85, 92, 94]
# Before Fine-tune, Test Accuracy: 0.02
# After One Hundred Iterations, Test Accuracy:0.88
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [2, 13, 20, 39, 46, 66, 69, 73, 76, 96]
# Before Fine-tune, Test Accuracy: 0.005
# After One Hundred Iterations, Test Accuracy:0.92
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [13, 18, 23, 25, 31, 41, 72, 90, 93, 95]
# Before Fine-tune, Test Accuracy: 0.01
# After One Hundred Iterations, Test Accuracy:0.9
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [11, 15, 22, 23, 25, 36, 49, 63, 79, 87]
# Before Fine-tune, Test Accuracy: 0.005
# After One Hundred Iterations, Test Accuracy:0.885
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [0, 26, 37, 44, 51, 64, 67, 73, 90, 94]
# Before Fine-tune, Test Accuracy: 0.0
# After One Hundred Iterations, Test Accuracy:0.93
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [8, 20, 32, 49, 65, 71, 82, 89, 89, 99]
# Before Fine-tune, Test Accuracy: 0.01
# After One Hundred Iterations, Test Accuracy:0.88
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [7, 14, 39, 70, 70, 80, 80, 81, 82, 91]
# Before Fine-tune, Test Accuracy: 0.005
# After One Hundred Iterations, Test Accuracy:0.965
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [3, 4, 14, 19, 45, 59, 63, 68, 78, 83]
# Before Fine-tune, Test Accuracy: 0.01
# After One Hundred Iterations, Test Accuracy:0.89
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [0, 11, 14, 28, 44, 51, 64, 70, 72, 75]
# Before Fine-tune, Test Accuracy: 0.01
# After One Hundred Iterations, Test Accuracy:0.905
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [7, 32, 38, 40, 49, 53, 54, 82, 88, 98]
# Before Fine-tune, Test Accuracy: 0.015
# After One Hundred Iterations, Test Accuracy:0.92
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [38, 38, 49, 49, 51, 53, 63, 73, 81, 84]
# Before Fine-tune, Test Accuracy: 0.0
# After One Hundred Iterations, Test Accuracy:0.94
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [19, 26, 28, 33, 40, 42, 47, 62, 77, 80]
# Before Fine-tune, Test Accuracy: 0.0
# After One Hundred Iterations, Test Accuracy:0.925
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [11, 11, 17, 20, 30, 55, 77, 83, 86, 99]
# Before Fine-tune, Test Accuracy: 0.02
# After One Hundred Iterations, Test Accuracy:0.935
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [2, 9, 9, 10, 32, 33, 44, 46, 58, 86]
# Before Fine-tune, Test Accuracy: 0.0
# After One Hundred Iterations, Test Accuracy:0.93
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [7, 14, 15, 24, 36, 49, 64, 70, 81, 92]
# Before Fine-tune, Test Accuracy: 0.015
# After One Hundred Iterations, Test Accuracy:0.895
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [6, 20, 21, 21, 53, 72, 83, 84, 87, 94]
# Before Fine-tune, Test Accuracy: 0.015
# After One Hundred Iterations, Test Accuracy:0.875
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [1, 7, 18, 30, 42, 52, 60, 75, 75, 76]
# Before Fine-tune, Test Accuracy: 0.005
# After One Hundred Iterations, Test Accuracy:0.895
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [7, 30, 32, 33, 38, 63, 86, 89, 94, 99]
# Before Fine-tune, Test Accuracy: 0.02
# After One Hundred Iterations, Test Accuracy:0.875
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [1, 4, 10, 30, 31, 39, 61, 67, 82, 97]
# Before Fine-tune, Test Accuracy: 0.015
# After One Hundred Iterations, Test Accuracy:0.87
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [15, 44, 44, 45, 64, 65, 71, 81, 81, 87]
# Before Fine-tune, Test Accuracy: 0.915
# After One Hundred Iterations, Test Accuracy:0.915
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [10, 11, 11, 34, 38, 40, 45, 53, 63, 85]
# Before Fine-tune, Test Accuracy: 0.01
# After One Hundred Iterations, Test Accuracy:0.91
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [5, 13, 21, 26, 37, 44, 60, 83, 87, 88]
# Before Fine-tune, Test Accuracy: 0.005
# After One Hundred Iterations, Test Accuracy:0.92
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [6, 15, 25, 28, 50, 68, 69, 75, 84, 90]
# Before Fine-tune, Test Accuracy: 0.015
# After One Hundred Iterations, Test Accuracy:0.87
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [4, 7, 15, 17, 20, 36, 48, 51, 74, 86]
# Before Fine-tune, Test Accuracy: 0.915
# After One Hundred Iterations, Test Accuracy:0.915
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [8, 24, 29, 32, 39, 44, 45, 85, 93, 98]
# Before Fine-tune, Test Accuracy: 0.01
# After One Hundred Iterations, Test Accuracy:0.895
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [31, 34, 55, 59, 61, 70, 72, 78, 88, 95]
# Before Fine-tune, Test Accuracy: 0.01
# After One Hundred Iterations, Test Accuracy:0.925
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [20, 24, 48, 49, 57, 58, 59, 69, 75, 96]
# Before Fine-tune, Test Accuracy: 0.01
# After One Hundred Iterations, Test Accuracy:0.885
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [15, 16, 22, 25, 26, 43, 64, 86, 94, 95]
# Before Fine-tune, Test Accuracy: 0.01
# After One Hundred Iterations, Test Accuracy:0.88
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [5, 12, 13, 29, 29, 44, 44, 58, 73, 79]
# Before Fine-tune, Test Accuracy: 0.015
# After One Hundred Iterations, Test Accuracy:0.925
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [5, 13, 37, 62, 73, 79, 79, 89, 90, 94]
# Before Fine-tune, Test Accuracy: 0.0
# After One Hundred Iterations, Test Accuracy:0.895
# ----------------------------------------------------------------------------------------------
# AVERAGE ACCURACY:  0.9052999973297119

# %% [markdown]
# ## 统计multi-class的accuracy平均数, num of classes:5

# %%
average = 0
for i in range(50):
    test_classes = np.random.randint(100,size=5)
    test_classes = test_classes.tolist()
    test_images, test_labels = data_loader.test.next_batch_without_onehot(200)
    test_labels = modify_label(test_labels, test_classes = test_classes)
    print("----------------------------------------------------------------------------------------------")
    model = FineTuneModel(target_class_id = test_classes)
    model.assign_weight()
    tmp = model.test_accuracy(test_images, test_labels)
    print("Class: ", test_classes)
    print("Before Fine-tune, Test Accuracy: " + str(tmp))
    for j in range(100):
        train_images, train_labels = data_loader.train.next_batch_without_onehot(500)
        train_labels = modify_label(train_labels, test_classes = test_classes)
        model.train_model(train_images, train_labels)
        accuracy = model.test_accuracy(test_images, test_labels)
        if (j == 99):
            print("After One Hundred Iterations, Test Accuracy:" + str(accuracy))
            average += accuracy
    print("----------------------------------------------------------------------------------------------")
print("AVERAGE ACCURACY: ",str(average*1.0/50))
# Out:
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [0, 23, 65, 73, 90]
# Before Fine-tune, Test Accuracy: 0.005
# After One Hundred Iterations, Test Accuracy:0.955
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [12, 20, 32, 49, 88]
# Before Fine-tune, Test Accuracy: 0.01
# After One Hundred Iterations, Test Accuracy:0.96
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [38, 44, 60, 60, 85]
# Before Fine-tune, Test Accuracy: 0.0
# After One Hundred Iterations, Test Accuracy:0.955
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [72, 75, 77, 82, 83]
# Before Fine-tune, Test Accuracy: 0.01
# After One Hundred Iterations, Test Accuracy:0.9
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [9, 44, 52, 54, 76]
# Before Fine-tune, Test Accuracy: 0.925
# After One Hundred Iterations, Test Accuracy:0.925
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [1, 25, 33, 57, 90]
# Before Fine-tune, Test Accuracy: 0.02
# After One Hundred Iterations, Test Accuracy:0.92
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [41, 41, 55, 85, 93]
# Before Fine-tune, Test Accuracy: 0.005
# After One Hundred Iterations, Test Accuracy:0.95
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [6, 14, 53, 80, 86]
# Before Fine-tune, Test Accuracy: 0.01
# After One Hundred Iterations, Test Accuracy:0.955
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [4, 15, 46, 52, 55]
# Before Fine-tune, Test Accuracy: 0.0
# After One Hundred Iterations, Test Accuracy:0.96
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [17, 35, 59, 60, 67]
# Before Fine-tune, Test Accuracy: 0.02
# After One Hundred Iterations, Test Accuracy:0.955
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [13, 42, 89, 89, 94]
# Before Fine-tune, Test Accuracy: 0.005
# After One Hundred Iterations, Test Accuracy:0.965
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [33, 54, 57, 70, 90]
# Before Fine-tune, Test Accuracy: 0.015
# After One Hundred Iterations, Test Accuracy:0.95
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [2, 59, 71, 77, 97]
# Before Fine-tune, Test Accuracy: 0.005
# After One Hundred Iterations, Test Accuracy:0.975
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [21, 48, 64, 70, 87]
# Before Fine-tune, Test Accuracy: 0.01
# After One Hundred Iterations, Test Accuracy:0.96
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [7, 8, 26, 29, 77]
# Before Fine-tune, Test Accuracy: 0.0
# After One Hundred Iterations, Test Accuracy:0.975
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [26, 54, 57, 60, 82]
# Before Fine-tune, Test Accuracy: 0.005
# After One Hundred Iterations, Test Accuracy:0.95
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [7, 15, 35, 53, 78]
# Before Fine-tune, Test Accuracy: 0.96
# After One Hundred Iterations, Test Accuracy:0.96
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [27, 30, 43, 88, 97]
# Before Fine-tune, Test Accuracy: 0.01
# After One Hundred Iterations, Test Accuracy:0.955
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [27, 32, 45, 58, 73]
# Before Fine-tune, Test Accuracy: 0.01
# After One Hundred Iterations, Test Accuracy:0.955
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [31, 39, 59, 62, 78]
# Before Fine-tune, Test Accuracy: 0.02
# After One Hundred Iterations, Test Accuracy:0.93
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [12, 15, 49, 59, 59]
# Before Fine-tune, Test Accuracy: 0.95
# After One Hundred Iterations, Test Accuracy:0.95
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [3, 22, 53, 65, 94]
# Before Fine-tune, Test Accuracy: 0.005
# After One Hundred Iterations, Test Accuracy:0.94
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [1, 17, 32, 49, 82]
# Before Fine-tune, Test Accuracy: 0.005
# After One Hundred Iterations, Test Accuracy:0.97
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [37, 50, 53, 79, 96]
# Before Fine-tune, Test Accuracy: 0.005
# After One Hundred Iterations, Test Accuracy:0.94
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [6, 61, 67, 85, 92]
# Before Fine-tune, Test Accuracy: 0.955
# After One Hundred Iterations, Test Accuracy:0.955
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [7, 37, 49, 72, 89]
# Before Fine-tune, Test Accuracy: 0.02
# After One Hundred Iterations, Test Accuracy:0.94
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [20, 49, 51, 72, 94]
# Before Fine-tune, Test Accuracy: 0.02
# After One Hundred Iterations, Test Accuracy:0.945
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [10, 11, 44, 89, 89]
# Before Fine-tune, Test Accuracy: 0.005
# After One Hundred Iterations, Test Accuracy:0.945
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [20, 41, 56, 68, 71]
# Before Fine-tune, Test Accuracy: 0.02
# After One Hundred Iterations, Test Accuracy:0.935
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [2, 13, 62, 65, 79]
# Before Fine-tune, Test Accuracy: 0.01
# After One Hundred Iterations, Test Accuracy:0.945
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [46, 86, 88, 90, 90]
# Before Fine-tune, Test Accuracy: 0.005
# After One Hundred Iterations, Test Accuracy:0.95
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [7, 24, 49, 72, 76]
# Before Fine-tune, Test Accuracy: 0.015
# After One Hundred Iterations, Test Accuracy:0.945
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [8, 26, 48, 79, 81]
# Before Fine-tune, Test Accuracy: 0.01
# After One Hundred Iterations, Test Accuracy:0.945
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [14, 29, 36, 57, 64]
# Before Fine-tune, Test Accuracy: 0.0
# After One Hundred Iterations, Test Accuracy:0.945
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [25, 28, 61, 65, 86]
# Before Fine-tune, Test Accuracy: 0.02
# After One Hundred Iterations, Test Accuracy:0.94
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [13, 44, 44, 59, 75]
# Before Fine-tune, Test Accuracy: 0.005
# After One Hundred Iterations, Test Accuracy:0.96
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [5, 23, 25, 29, 88]
# Before Fine-tune, Test Accuracy: 0.015
# After One Hundred Iterations, Test Accuracy:0.945
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [16, 19, 37, 77, 89]
# Before Fine-tune, Test Accuracy: 0.01
# After One Hundred Iterations, Test Accuracy:0.95
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [27, 41, 66, 83, 86]
# Before Fine-tune, Test Accuracy: 0.015
# After One Hundred Iterations, Test Accuracy:0.935
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [18, 37, 45, 75, 90]
# Before Fine-tune, Test Accuracy: 0.035
# After One Hundred Iterations, Test Accuracy:0.915
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [17, 19, 21, 51, 91]
# Before Fine-tune, Test Accuracy: 0.005
# After One Hundred Iterations, Test Accuracy:0.95
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [11, 26, 41, 66, 96]
# Before Fine-tune, Test Accuracy: 0.955
# After One Hundred Iterations, Test Accuracy:0.955
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [4, 5, 6, 9, 22]
# Before Fine-tune, Test Accuracy: 0.02
# After One Hundred Iterations, Test Accuracy:0.955
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [28, 37, 52, 58, 94]
# Before Fine-tune, Test Accuracy: 0.005
# After One Hundred Iterations, Test Accuracy:0.95
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [25, 31, 32, 40, 47]
# Before Fine-tune, Test Accuracy: 0.015
# After One Hundred Iterations, Test Accuracy:0.925
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [4, 35, 52, 79, 91]
# Before Fine-tune, Test Accuracy: 0.005
# After One Hundred Iterations, Test Accuracy:0.945
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [5, 23, 32, 49, 85]
# Before Fine-tune, Test Accuracy: 0.0
# After One Hundred Iterations, Test Accuracy:0.955
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [18, 41, 42, 75, 78]
# Before Fine-tune, Test Accuracy: 0.005
# After One Hundred Iterations, Test Accuracy:0.97
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [16, 36, 61, 74, 84]
# Before Fine-tune, Test Accuracy: 0.005
# After One Hundred Iterations, Test Accuracy:0.965
# ----------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# restored the pretrained model......
# INFO:tensorflow:Restoring parameters from vggNet/augmentation.ckpt-120
# Restored successfully!
# RUNNING mask_class_multi_by_value.py
# Class:  [0, 29, 54, 61, 81]
# Before Fine-tune, Test Accuracy: 0.945
# After One Hundred Iterations, Test Accuracy:0.945
# ----------------------------------------------------------------------------------------------
# AVERAGE ACCURACY:  0.9483999931812286
